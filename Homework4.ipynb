# %% [markdown]
# # PyCity Schools Analysis

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load 
school_data_to_load ="../Pandas-Homework-4/PyCitySchools/Resources/schools_complete.csv"
student_data_to_load ="../Pandas-Homework-4/PyCitySchools/Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
df = pd.merge(student_data, school_data, how="left", on=["school_name"])
df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
school_data
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
student_data.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# calculating mean scores
student_mean = student_data.groupby(["school_name"]).mean()
student_mean
# Out:
#                        Student ID  reading_score  math_score
# school_name
# Bailey High School        20358.5      81.033963   77.048432
# Cabrera High School       16941.5      83.975780   83.061895
# Figueroa High School       4391.0      81.158020   76.711767
# Ford High School          36165.0      80.746258   77.102592
# Griffin High School       12995.5      83.816757   83.351499
# Hernandez High School      9944.0      80.934412   77.289752
# Holden High School        23060.0      83.814988   83.803279
# Huang High School          1458.0      81.182722   76.629414
# Johnson High School       32415.0      80.966394   77.072464
# Pena High School          23754.5      84.044699   83.839917
# Rodriguez High School     28035.0      80.744686   76.842711
# Shelton High School        6746.0      83.725724   83.359455
# Thomas High School        38352.0      83.848930   83.418349
# Wilson High School        14871.0      83.989488   83.274201
# ...

# %% [markdown]
# ## creating a list of 1 term - the number of scools

# %%
# row count = number of schools
schools_count_row = school_data.shape[0]  

total_schools = [schools_count_row]
total_schools
# Out:
# [15]

# %%
# row count = number of students
students_count_row = student_data.shape[0] 

total_students = [students_count_row]
total_students
# Out:
# [39170]

# %%
total_budget = [school_data["budget"].sum()]
total_budget
# Out:
# [24649428]

# %%
average_math_score = [student_data["math_score"].mean()]
average_math_score
# Out:
# [78.98537145774827]

# %%
#finding the number that passed math
passing_math = student_data.loc[student_data["math_score"] >= 70]
num_passing_math = [passing_math.shape[0]]
num_passing_math
# Out:
# [29370]

# %%
math_pass_percent = [num_passing_math[0] / total_students[0]]
math_pass_percent
# Out:
# [0.749808526933878]

# %%
average_reading_score = [student_data["reading_score"].mean()]
average_reading_score
# Out:
# [81.87784018381414]

# %%
#finding the number that passed reading
passing_reading = student_data.loc[student_data["reading_score"] >= 70]
num_passing_reading = [passing_reading.shape[0]]
num_passing_reading
# Out:
# [33610]

# %%
reading_pass_percent = [num_passing_reading[0] / total_students[0]]
reading_pass_percent
# Out:
# [0.8580546336482001]

# %%
overall_passing_rate = [(average_math_score[0] + average_reading_score[0]) / 2]
overall_passing_rate
# Out:
# [80.43160582078121]

# %%
# creating table for district summary
district_summary_df = pd.DataFrame({
    "Total Schools": total_schools,
    "Total Students": total_students,
    "Total Budget": total_budget,
    "Average Math Score": average_math_score,
    "Average Reading Score": average_reading_score,
    "% Passing Math": math_pass_percent,
    "% Passing Reading": reading_pass_percent,
    "% Overall Passing Rate": overall_passing_rate
})
district_summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784        0.749809           0.858055
#
#    % Overall Passing Rate
# 0               80.431606

# %% [markdown]
# School Type	Total Students	Total School Budget	Per Student Budget	Average Math Score	Average Reading Score	% Passing Math	% Passing Reading	% Overall Passing Rat

# %%
# grouping the combined data by school name and averaging scores
df= df.groupby(['school_name']).mean()
df
# Out:
#                        Student ID  reading_score  math_score  School ID  \
# school_name
# Bailey High School        20358.5      81.033963   77.048432        7.0
# Cabrera High School       16941.5      83.975780   83.061895        6.0
# Figueroa High School       4391.0      81.158020   76.711767        1.0
# Ford High School          36165.0      80.746258   77.102592       13.0
# Griffin High School       12995.5      83.816757   83.351499        4.0
# Hernandez High School      9944.0      80.934412   77.289752        3.0
# Holden High School        23060.0      83.814988   83.803279        8.0
# Huang High School          1458.0      81.182722   76.629414        0.0
# Johnson High School       32415.0      80.966394   77.072464       12.0
# Pena High School          23754.5      84.044699   83.839917        9.0
# Rodriguez High School     28035.0      80.744686   76.842711       11.0
# Shelton High School        6746.0      83.725724   83.359455        2.0
# ...

# %%
del df["Student ID"]
del df["School ID"]

# %%
# calculating per student budget and adding to df 
df["Per Student Budget"] = df["budget"] / df["size"]

# %%
del df['size']
del df['budget']

# %%
# mering new df to school data 
df = pd.merge(df, school_data, how="left", on=["school_name"])
df
# Out:
#               school_name  reading_score  math_score  Per Student Budget  \
# 0      Bailey High School      81.033963   77.048432               628.0
# 1     Cabrera High School      83.975780   83.061895               582.0
# 2    Figueroa High School      81.158020   76.711767               639.0
# 3        Ford High School      80.746258   77.102592               644.0
# 4     Griffin High School      83.816757   83.351499               625.0
# 5   Hernandez High School      80.934412   77.289752               652.0
# 6      Holden High School      83.814988   83.803279               581.0
# 7       Huang High School      81.182722   76.629414               655.0
# 8     Johnson High School      80.966394   77.072464               650.0
# 9        Pena High School      84.044699   83.839917               609.0
# 10  Rodriguez High School      80.744686   76.842711               637.0
# 11    Shelton High School      83.725724   83.359455               600.0
# ...

# %%
passing_math.set_index("school_name")
# Out:
#                     Student ID         student_name gender grade  \
# school_name
# Huang High School            0         Paul Bradley      M   9th
# Huang High School            4           Bonnie Ray      F   9th
# Huang High School            5        Bryan Miranda      M   9th
# Huang High School            6        Sheena Carter      F  11th
# Huang High School            8         Michael Roth      M  10th
# Huang High School            9       Matthew Greene      M  10th
# Huang High School           10     Andrew Alexander      M  10th
# Huang High School           11        Daniel Cooper      M  10th
# Huang High School           12      Brittney Walker      F   9th
# Huang High School           13         William Long      M   9th
# Huang High School           15    Dr. Jordan Carson      M  11th
# Huang High School           17    Kimberly Santiago      F   9th
# Huang High School           19         Brandi Lyons      F   9th
# ...

# %%
# counting number of students that passed math at each school
passmathschools = passing_math[['school_name','math_score']].groupby(['school_name']).count()
passmathschools
# Out:
#                        math_score
# school_name
# Bailey High School           3318
# Cabrera High School          1749
# Figueroa High School         1946
# Ford High School             1871
# Griffin High School          1371
# Hernandez High School        3094
# Holden High School            395
# Huang High School            1916
# Johnson High School          3145
# Pena High School              910
# Rodriguez High School        2654
# Shelton High School          1653
# Thomas High School           1525
# Wilson High School           2143
# Wright High School           1680

# %%
passmathschools.reset_index(inplace=True)
passmathschools
# Out:
#               school_name  math_score
# 0      Bailey High School        3318
# 1     Cabrera High School        1749
# 2    Figueroa High School        1946
# 3        Ford High School        1871
# 4     Griffin High School        1371
# 5   Hernandez High School        3094
# 6      Holden High School         395
# 7       Huang High School        1916
# 8     Johnson High School        3145
# 9        Pena High School         910
# 10  Rodriguez High School        2654
# 11    Shelton High School        1653
# 12     Thomas High School        1525
# 13     Wilson High School        2143
# 14     Wright High School        1680

# %%
# counting the number of students that passed reading at each school
passreadingschools = passing_reading[['school_name','reading_score']].groupby(['school_name']).count()

# %%
passreadingschools.reset_index(inplace=True)

# %%
# adding columns to dataframef
df["Num Passing Math"] = passmathschools["math_score"]
df["Num Passing Reading"] = passreadingschools["reading_score"]
df["% Passing Math"] = df["Num Passing Math"] / df["size"]*100
df["% Passing Reading"] = df["Num Passing Reading"] / df["size"]*100

# %%
# calculating overall passing rate
df["% Overall Passing Rate"] = (df["% Passing Reading"] + df["% Passing Math"] )/2

# %%
del df["Num Passing Math"]
del df["Num Passing Reading"]

# %%
# arrange by top overall percent rate
by_passing_rate_df = df.sort_values(by='% Overall Passing Rate', ascending = False)

# %%
# renaming columns

by_passing_rate_df = by_passing_rate_df.rename(columns={'reading_score': 'Average Reading Score', 'math_score' : 'Average Math Score',
                                    'type': 'School Type', 'size': 'Total Students', 'budget': 'Total School Budget'})

# %%
# set index to school name
by_passing_rate_df.set_index('school_name', inplace = True)

# %%
# remove idex
del by_passing_rate_df.index.name

# %%
# change column order
by_passing_rate_df = by_passing_rate_df[['School Type', 'Total Students', 'Total School Budget', 'Per Student Budget', 'Average Math Score', 
                     'Average Reading Score', '% Passing Math', '% Passing Reading', '% Overall Passing Rate']]

# %%
# changing the format of budget columns
# displaying top five schools by overall pasing rate
by_passing_rate_df['Total School Budget'] = by_passing_rate_df['Total School Budget'].map('${:,.2f}'.format)
by_passing_rate_df['Per Student Budget'] = by_passing_rate_df['Per Student Budget'].map('${:,.2f}'.format)
top_five = by_passing_rate_df.head(5)
top_five
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858       $1,081,356.00
# Thomas High School      Charter            1635       $1,043,130.00
# Pena High School        Charter             962         $585,858.00
# Griffin High School     Charter            1468         $917,500.00
# Wilson High School      Charter            2283       $1,319,574.00
#
#                     Per Student Budget  Average Math Score  \
# Cabrera High School            $582.00           83.061895
# Thomas High School             $638.00           83.418349
# Pena High School               $609.00           83.839917
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %%
# displaying bottom five by overall passing rate
by_passing_rate_df = by_passing_rate_df.sort_values(by='% Overall Passing Rate', ascending = True)
by_passing_rate_df.head(5)
# Out:
#                       School Type  Total Students Total School Budget  \
# Rodriguez High School    District            3999       $2,547,363.00
# Figueroa High School     District            2949       $1,884,411.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Ford High School         District            2739       $1,763,916.00
#
#                       Per Student Budget  Average Math Score  \
# Rodriguez High School            $637.00           76.842711
# Figueroa High School             $639.00           76.711767
# Huang High School                $655.00           76.629414
# Johnson High School              $650.00           77.072464
# Ford High School                 $644.00           77.102592
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# ...
